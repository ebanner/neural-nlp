# %% [markdown]
# ### Read Result From Training

# %%
ls store/hyperparams/
# Out:
# aux/                        just_features/                predict_just_neural/
# blmsml_save_probas/         just_neural/                  predict_on_batch/
# bulk_lm_score_more_layers/  linear/                       predict_on_batches/
# bulk_lm_scores/             linear_ensemble/              predict_test/
# embeddings/                 lstm/                         predict_test_train/
# ensemble/                   mlp/                          random_variable/
# features_cv/                predict/                      test/
# foo/                        predict_just_features/        tok_test/
# ichi_d2v/                   predict_just_features_train/  variety/

# %%
from curves import LearningCurveVisualizer

lv = LearningCurveVisualizer(exp_group='random_variable')

lv.best_runs()
# Out:
#         val_main_acc  best_main_mu  best_main_range  best_main  worst_main  \
# exp-id
# 0            0.63625       0.63625              0.0    0.63625     0.63625
#
#         best_epoch callbacks dropout-prob        exp-group  \
# exp-id
# 0                5  fl,cv,rv       1e-100  random_variable
#
#                          features inputs nb-epoch     trainer
# exp-id
# 0       bulk_lm_scores_minus_ichi   None       12  AuxTrainer

# %%
lv.learning_curves

# %%
lv.validation_curves
